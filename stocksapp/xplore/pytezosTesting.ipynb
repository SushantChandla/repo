# %%
from pytezos import pytezos

# %%
pyt =pytezos.using(key="edskRotpJzJHWX4zLsbuyfVnjeojJ3pmysGJEuXSvQWSvBqG1mS4x24TFjQhpiZQpKYNhzJT1DMfXbAE2YKVcuZE6fniECGeRB",shell="https://edonet.smartpy.io")

# %%
contr=pyt.contract("KT1QNvidZC8e5U2UNnv72LUpDtoKfhzu1dge")

# %%
contr.storage()
# Out:
# ---------------------------------------------------------------------------
# MichelsonRuntimeError                     Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     306     try:
# --> 307         res = func(val_expr, type_expr, selector, type_path)
#     308     except AssertionError as e:
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_list(val_expr, type_expr, selector, type_path)
#     355     assert_type(val_expr, list)
# --> 356     val = [parse_expression(item, type_expr['args'][0], selector, type_path + '0') for item in val_expr]
#     357     return selector(val_expr, type_expr, val, type_path)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in <listcomp>(.0)
#     355     assert_type(val_expr, list)
# --> 356     val = [parse_expression(item, type_expr['args'][0], selector, type_path + '0') for item in val_expr]
#     357     return selector(val_expr, type_expr, val, type_path)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     304     """
# --> 305     prim, _, func = parse_type(type_expr)
#     306     try:
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_type(type_expr)
#     265     if len(args) != args_len:
# --> 266         raise MichelsonRuntimeError.init(f'expected {args_len} arg(s), got {len(args)}', prim)
#     267
#
# MichelsonRuntimeError: expected 2 arg(s), got 4: pair
#
# During handling of the above exception, another exception occurred:
#
# MichelsonTypeCheckError                   Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     306     try:
# --> 307         res = func(val_expr, type_expr, selector, type_path)
#     308     except AssertionError as e:
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_map(val_expr, type_expr, selector, type_path)
#     401     assert_comparable(type_expr['args'][0])
# --> 402     val = [parse_elt(item, type_expr, selector, type_path) for item in val_expr]
#     403     return selector(val_expr, type_expr, val, type_path)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in <listcomp>(.0)
#     401     assert_comparable(type_expr['args'][0])
# --> 402     val = [parse_elt(item, type_expr, selector, type_path) for item in val_expr]
#     403     return selector(val_expr, type_expr, val, type_path)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_elt(val_expr, type_expr, selector, type_path)
#     394     elt_args = get_prim_args(val_expr, prim='Elt', args_len=2)
# --> 395     return [parse_expression(elt_args[i], type_expr['args'][i], selector, type_path + str(i)) for i in [0, 1]]
#     396
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in <listcomp>(.0)
#     394     elt_args = get_prim_args(val_expr, prim='Elt', args_len=2)
# --> 395     return [parse_expression(elt_args[i], type_expr['args'][i], selector, type_path + str(i)) for i in [0, 1]]
#     396
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     310     except MichelsonRuntimeError as e:
# --> 311         raise MichelsonTypeCheckError.wrap(e, prim)
#     312     else:
#
# MichelsonTypeCheckError: expected 2 arg(s), got 4: list -> pair
#
# During handling of the above exception, another exception occurred:
#
# MichelsonTypeCheckError                   Traceback (most recent call last)
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     306     try:
# --> 307         res = func(val_expr, type_expr, selector, type_path)
#     308     except AssertionError as e:
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_pair(val_expr, type_expr, selector, type_path)
#     362     args = get_prim_args(val_expr, prim='Pair', args_len=2)
# --> 363     val = [parse_expression(args[i], type_expr['args'][i], selector, type_path + str(i)) for i in [0, 1]]
#     364     return selector(val_expr, type_expr, val, type_path)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in <listcomp>(.0)
#     362     args = get_prim_args(val_expr, prim='Pair', args_len=2)
# --> 363     val = [parse_expression(args[i], type_expr['args'][i], selector, type_path + str(i)) for i in [0, 1]]
#     364     return selector(val_expr, type_expr, val, type_path)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     310     except MichelsonRuntimeError as e:
# --> 311         raise MichelsonTypeCheckError.wrap(e, prim)
#     312     else:
#
# MichelsonTypeCheckError: expected 2 arg(s), got 4: map -> list -> pair
#
# During handling of the above exception, another exception occurred:
#
# MichelsonTypeCheckError                   Traceback (most recent call last)
# <ipython-input-24-1a0fbcfdb29b> in <module>
# ----> 1 contr.storage()
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/tools/docstring.py in __call__(self, *args, **kwargs)
#      65
#      66                 def __call__(self, *args, **kwargs):
# ---> 67                     return method(self.class_instance, *args, **kwargs)
#      68
#      69                 def __repr__(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/michelson/interface.py in storage(self, block_id)
#     408         """
#     409         storage = self.shell.blocks[block_id].context.contracts[self.address].storage()
# --> 410         return self.contract.storage.decode(storage)
#     411
#     412     def operation_result(self, operation_group: dict) -> List[ContractCallResult]:
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/tools/docstring.py in __call__(self, *args, **kwargs)
#      65
#      66                 def __call__(self, *args, **kwargs):
# ---> 67                     return method(self.class_instance, *args, **kwargs)
#      68
#      69                 def __repr__(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/michelson/contract.py in decode(self, data)
#     136         if isinstance(data, str):
#     137             data = michelson_to_micheline(data)
# --> 138         return decode_micheline(val_expr=data,
#     139                                 type_expr=self.code,
#     140                                 schema=self.schema)
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/michelson/converter.py in decode_micheline(val_expr, type_expr, schema, root)
#      43     """
#      44     try:
# ---> 45         return parse_micheline(val_expr, type_expr, schema, root)
#      46     except (KeyError, IndexError, TypeError) as e:
#      47         print(generate_docstring(schema, 'schema'))
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/michelson/micheline.py in parse_micheline(val_expr, type_expr, schema, bin_root)
#     253         type_expr = type_expr['args'][int(idx)]
#     254
# --> 255     return parse_expression(val_expr, type_expr, decode_selector, bin_root)
#     256
#     257
#
# ~/Library/Python/3.8/lib/python/site-packages/pytezos/repl/parser.py in parse_expression(val_expr, type_expr, selector, type_path)
#     309         raise MichelsonTypeCheckError.init(str(e), prim)
#     310     except MichelsonRuntimeError as e:
# --> 311         raise MichelsonTypeCheckError.wrap(e, prim)
#     312     else:
#     313         return res
#
# MichelsonTypeCheckError: expected 2 arg(s), got 4: pair -> map -> list -> pair

# %%
li=[1,2]
li[0:20]
# Out:
# [1, 2]

# %%
contr.addTransaction(
                username="username",
                stockType="stockid_in",
                price=30,
                quantity=40,
                to_from="Organization"
            ).operation_group.sign().inject()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-1e18979cec84> in <module>
# ----> 1 contr.addTransaction(
#       2                 username="username",
#       3                 stockType="stockid_in",
#       4                 price=30,
#       5                 quantity=40,
#
# AttributeError: 'ContractInterface' object has no attribute 'addTransaction'

# %%
contr.storage()

# %%
print(contr.storage())
